# %%
import requests
import pandas as pd

# %%
import mysql.connector
from mysql.connector import Error
import numpy as np

# %%
import os

# %%
import requests
import pandas as pd

def conseguir_canciones(artist_name, limit=50):     # Función para conseguir 50 canciones de la artista que quieras
    url = "https://api.deezer.com/search"           # URL base de la API para buscar
    params = {                                      # Para insertar los parámetros de la búsqueda
        "q": f'artist:"{artist_name}"',             # La API busca artista por q
        "limit": limit                              # Limit sirve para que saque solo 50
    }
    try:                                            # Bloque try/excep para llamar a la API y que nos dé el resultado
        response = requests.get(url, params=params)
        if response.status_code != 200:
            print("Error en la llamada a Deezer:", response.status_code)    # Si falla lo va a informar
            return pd.DataFrame([])                                         # Y también nos va a devolver el DF vacío
        data = response.json()                                              # Si no falla da la respuesta en json
    except Error as e:
        print("Error en la llamada a Deezer:", e)                           # Para que nos diga exactamente cuál es el error
        return pd.DataFrame([])

    canciones = data.get("data", [])                # Obtiene la lista de canciones
    lista_canciones = []                            # Lista donde se van a acumular las filas para el DF final

    for cancion in canciones:                       # Bucle para que itere con todas las canciones y nos vaya dando los datos
        track_id = cancion["id"]                    # Nos da el id de la canción
        track = requests.get(f"https://api.deezer.com/track/{track_id}").json()  # Pide todos los datos que estén en track
        album = requests.get(f"https://api.deezer.com/album/{track['album']['id']}").json() # Pide todos los datos que estén en album

        genre_id = album.get("genre_id")   # Extrae el ID del género de album
        genre_name = None                  # Creamos la variable "vacía"
        if album.get("genres") and album["genres"].get("data"):   # Le decimoa que en el caso de que genres exista en album
            genre_name = album["genres"]["data"][0].get("name")   # Entonces nos diga el primer género que aparezca (por si hay varios)

        tracks_type = "colaboracion" if len(track.get("contributors", [])) > 1 else album.get("record_type", "track")
        # Buscamos colaboraciones. Para ello, si en contributor aparece más de 1, entonces se trata de una colaboración
        # Si no, le decimos que nos ponga lo que aparezca en record_type que es single o album, y si no que ponga track
        release_year = track.get("release_date", "")[:4] if track.get("release_date") else None
        # Obtiene el año de lanzamiento solo si hay 4 cifras, si no pondrá None 
        lista_canciones.append({                   # Creamos un diccionario para añadir todos los datos que necesitamos
            "id_artista": track["artist"]["id"],
            "nombre_artista": artist_name,
            "titulo_cancion": track["title"],
            "titulo_album": track["album"]["title"],
            "tipo": tracks_type,
            "año_lanzamiento": release_year,
            "genero": genre_name,
            "id_genero": genre_id,
        })

    return pd.DataFrame(lista_canciones)        # Hacemos que nos devuelta el resultado en un DF

df_artista = conseguir_canciones("Janis Joplin", limit=50)
df_artista
# Out:
#     id_artista nombre_artista  \
# 0        13840   Janis Joplin
# 1         1658   Janis Joplin
# 2         1658   Janis Joplin
# 3         1658   Janis Joplin
# 4        13840   Janis Joplin
# 5        13840   Janis Joplin
# 6         1658   Janis Joplin
# 7         1658   Janis Joplin
# 8        13840   Janis Joplin
# 9         1658   Janis Joplin
# 10        1658   Janis Joplin
# 11        1658   Janis Joplin
# 12        1658   Janis Joplin
# 13       13840   Janis Joplin
# 14        1658   Janis Joplin
# 15        1658   Janis Joplin
# 16        1658   Janis Joplin
# 17        1658   Janis Joplin
# 18       13840   Janis Joplin
# 19       13840   Janis Joplin
# 20       13840   Janis Joplin
# 21        1658   Janis Joplin
# 22        1658   Janis Joplin
# 23        1658   Janis Joplin
# 24        1658   Janis Joplin
# 25       13840   Janis Joplin
# 26        1658   Janis Joplin
# 27        1658   Janis Joplin
# 28       13840   Janis Joplin
# 29        1658   Janis Joplin
# 30       13840   Janis Joplin
# 31      455579   Janis Joplin
# 32       69919   Janis Joplin
# 33        1658   Janis Joplin
# 34        1658   Janis Joplin
# 35        1658   Janis Joplin
# 36       13840   Janis Joplin
# 37        1658   Janis Joplin
# 38        1658   Janis Joplin
# 39        1658   Janis Joplin
# 40       13840   Janis Joplin
# 41       13840   Janis Joplin
# 42        1658   Janis Joplin
# 43       69919   Janis Joplin
# 44       69919   Janis Joplin
# 45        1658   Janis Joplin
# 46       69919   Janis Joplin
# 47       13840   Janis Joplin
# 48        1658   Janis Joplin
# 49        1658   Janis Joplin
#
#                                        titulo_cancion  \
# 0                                   Piece of My Heart
# 1                                  Me and Bobby McGee
# 2                                            Cry Baby
# 3                                        Kozmic Blues
# 4                                          Call On Me
# 5                                          Summertime
# 6                                    Little Girl Blue
# 7                                           Move Over
# 8                                      Ball and Chain
# 9                                               Maybe
# 10                       Cry Baby (Alternate Version)
# 11  Piece Of My Heart (Live at The Woodstock Music...
# 12                                   To Love Somebody
# 13                                      Bye, Bye Baby
# 14                                      Mercedes Benz
# 15                               Get It While You Can
# 16                     Try (Just a Little Bit Harder)
# 17                                   Little Girl Blue
# 18                           Coo Coo (Single Version)
# 19                              Turtle Blues (Take 9)
# 20  Down On Me (Live at The Grande Ballroom, Detro...
# 21  Kozmic Blues (Live at CNE Stadium, Toronto, Ca...
# 22  Move Over (Live at McMahon Stadium, Calgary, C...
# 23  Summertime (Live at The Woodstock Music & Art ...
# 24                                          Half Moon
# 25  Piece of My Heart (Live at The Grande Ballroom...
# 26  Take Another Piece of my Heart (Live SWR TV Fr...
# 27                               Pearl (Instrumental)
# 28                                     Ball and Chain
# 29                        My Baby (Alternate Version)
# 30                                           Blindman
# 31                                    One Night Stand
# 32                                     Oh, Sweet Mary
# 33                                       One Good Man
# 34  Cry Baby (Live at McMahon Stadium, Calgary, Ca...
# 35                                A Woman Left Lonely
# 4             1999   Rock        152
# 5             2003   Rock        152
# 6             1969   Rock        152
# 7             1971    Pop        132
# 8             2017   Rock        152
# 9             2016   Rock        152
# 10            1971   Rock        152
# 11            2009   Rock        152
# 12            1969   Rock        152
# 13            1973    Pop        132
# 14            1971   Rock        152
# 15            1971   Rock        152
# 16            1969   Rock        152
# 17            2016   Rock        152
# 18            2003   Rock        152
# 19            2018   Rock        152
# 20            1973    Pop        132
# 21            1971   Rock        152
# 22            1971   Rock        152
# 23            2009   Rock        152
# 24            1971    Pop        132
# 25            1972   Rock        152
# 26            2017   Rock        152
# 27            1971   Rock        152
# 28            1999   Rock        152
# 29            1971   Rock        152
# 30            1967   Rock        152
# 31            1981   Rock        152
# 32            1968   Rock        152
# 33            1969   Rock        152
# 34            2016   Rock        152
# 35            1971    Pop        132
# 36            1998   Rock        152
# 37            1971   Rock        152
# 38            1971   Rock        152
# 39            1971   Rock        152
# 40            1998   Rock        152
# 41            2026   Rock        152
# 42            1969   Rock        152
# 43            1968   Rock        152
# 44            1968   Rock        152
# 45            1971   Rock        152
# 46            1968   Rock        152
# 47            2003   Rock        152
# 48            2019   Rock        152
# 49            1973    Pop        132

# %%
df_artista.to_csv("janis.csv", index=False)

# %%
def conseguir_canciones(artist_name, limit=50):     # Función para conseguir 50 canciones de la artista que quieras
    url = "https://api.deezer.com/search"           # URL base de la API para buscar
    params = {                                      # Para insertar los parámetros de la búsqueda
        "q": f'artist:"{artist_name}"',             # La API busca artista por q
        "limit": limit                              # Limit sirve para que saque solo 50
    }
    try:                                            # Bloque try/excep para llamar a la API y que nos dé el resultado
        response = requests.get(url, params=params)
        if response.status_code != 200:
            print("Error en la llamada a Deezer:", response.status_code)    # Si falla lo va a informar
            return pd.DataFrame([])                                         # Y también nos va a devolver el DF vacío
        data = response.json()                                              # Si no falla da la respuesta en json
    except Error as e:
        print("Error en la llamada a Deezer:", e)                           # Para que nos diga exactamente cuál es el error
        return pd.DataFrame([])

    canciones = data.get("data", [])                # Obtiene la lista de canciones
    lista_canciones = []                            # Lista donde se van a acumular las filas para el DF final

    for cancion in canciones:                       # Bucle para que itere con todas las canciones y nos vaya dando los datos
        track_id = cancion["id"]                    # Nos da el id de la canción
        track = requests.get(f"https://api.deezer.com/track/{track_id}").json()  # Pide todos los datos que estén en track
        album = requests.get(f"https://api.deezer.com/album/{track['album']['id']}").json() # Pide todos los datos que estén en album

        genre_id = album.get("genre_id")   # Extrae el ID del género de album
        genre_name = None                  # Creamos la variable "vacía"
        if album.get("genres") and album["genres"].get("data"):   # Le decimoa que en el caso de que genres exista en album
            genre_name = album["genres"]["data"][0].get("name")   # Entonces nos diga el primer género que aparezca (por si hay varios)

        tracks_type = "colaboracion" if len(track.get("contributors", [])) > 1 else album.get("record_type", "track")
        # Buscamos colaboraciones. Para ello, si en contributor aparece más de 1, entonces se trata de una colaboración
        # Si no, le decimos que nos ponga lo que aparezca en record_type que es single o album, y si no que ponga track
        release_year = track.get("release_date", "")[:4] if track.get("release_date") else None
        # Obtiene el año de lanzamiento solo si hay 4 cifras, si no pondrá None 
        lista_canciones.append({                   # Creamos un diccionario para añadir todos los datos que necesitamos
            "id_artista": track["artist"]["id"],
            "nombre_artista": artist_name,
            "titulo_cancion": track["title"],
            "titulo_album": track["album"]["title"],
            "tipo": tracks_type,
            "año_lanzamiento": release_year,
            "genero": genre_name,
            "id_genero": genre_id,
        })

    return pd.DataFrame(lista_canciones)        # Hacemos que nos devuelta el resultado en un DF

df_artista = conseguir_canciones("Celia Cruz", limit=50)
df_artista
# Out:
#     id_artista nombre_artista  \
# 0         5024     Celia_Cruz
# 1         2789     Celia_Cruz
# 2         5024     Celia_Cruz
# 3         5024     Celia_Cruz
# 4        84998     Celia_Cruz
# 5      4106065     Celia_Cruz
# 6         5024     Celia_Cruz
# 7        84998     Celia_Cruz
# 8         5678     Celia_Cruz
# 9         5002     Celia_Cruz
# 10       84998     Celia_Cruz
# 11        5024     Celia_Cruz
# 12        5024     Celia_Cruz
# 13        5024     Celia_Cruz
# 14      191162     Celia_Cruz
# 15      191162     Celia_Cruz
# 16        5024     Celia_Cruz
# 17        5024     Celia_Cruz
# 18        5024     Celia_Cruz
# 19      279489     Celia_Cruz
# 20        5024     Celia_Cruz
# 21        5024     Celia_Cruz
# 22        5024     Celia_Cruz
# 23        5024     Celia_Cruz
# 24        5024     Celia_Cruz
# 25        5024     Celia_Cruz
# 26     4135917     Celia_Cruz
# 27        5024     Celia_Cruz
#
#                                        titulo_cancion  \
# 0                              La Vida Es Un Carnaval
# 1             El Ultimo Adiós Varios Artistas Version
# 2                               La Negra Tiene Tumbao
# 3                                         Oye Cómo Va
# 4                                            Quimbara
# 5                   Quizas, Quizas, Quizas - Original
# 6                                         Rie y Llora
# 7                                   Canto A La Habana
# 8                          A lo loco (con Celia Cruz)
# 9   Tres Gotas De Agua Bendita (feat. Celia Cruz) ...
# 10                                        No Mercedes
# 11                                        Usted Abusó
# 12                                       Guantanamera
# 13                           Yo Viviré I Will Survive
# 14                                         Burundanga
# 15                                       Pa La Paloma
# 16                                      Mi Bomba Sono
# 17                                       Bemba Colorá
# 18                            Dile Que por Mí No Tema
# 19                                              Celia
# 20                         Óyela, Gózala (Remastered)
# 21                       No me mires más (Remastered)
# 22                       El Lleva y Trae (Remastered)
# 23                          Palo Mayimbe (Remastered)
# 24                              El Congo (Remastered)
# 25                          Pepe Antonio (Remastered)
# 26                          Hay Comentario - Original
# 27                                         Bembelequa
#
#                                          titulo_album          tipo  \
# 0                La Vida Es Un Carnaval (Baile Total)         album
# 1                                     El Ultimo Adiós  colaboracion
# 2                               La Reina Y Sus Amigos         album
# 3                 Fania Records: The 60's, Vol. Three  colaboracion
# 4                                 Salsa Party, Vol. 2  colaboracion
# 5                                     Salsa Queen CD3       compile
# 6                                           Soy Mujer         album
# 7         Fania Classics: Celia Cruz & Johnny Pacheco  colaboracion
# 8                              A Lo Loco Con P. Tinto  colaboracion
# 9                          Tres Gotas De Agua Bendita  colaboracion
# 10        Fania Classics: Celia Cruz & Johnny Pacheco  colaboracion
# 11                                              Celia  colaboracion
# 12                          50 éxitos de salsa cubana         album
# 13                                    Regalo Del Alma         album
# 14                                   Canta Celia Cruz  colaboracion
# 15                             Cuba's Queen Of Rhythm  colaboracion
# 16                                        Salsa Queen         album
# 17                          Viva la Reina de la Salsa         album
# 18  Antología Romántica: Grandes Voces, Grandes Bo...  colaboracion
# 19                                          Demasiado  colaboracion
# 20                       Yerbero Moderno (Remastered)         album
# 21                            Burundanga (Remastered)         album
# 22                         Pa' la Paloma (Remastered)         album
# 23                   La Isla del Encanto (Remastered)         album
# 24                   La Isla del Encanto (Remastered)         album
# 25                   La Isla del Encanto (Remastered)         album
# 26                                 Queen Of The Rumba       compile
# 27                                      Sábado Alegre         album
#
#    año_lanzamiento   genero  id_genero
# 0             2017   Latino        197
# 1             2001      Pop        132
# 2             2009   Latino        197
# 3             2019   Latino        197
# 4             2019   Latino        197
# 5             2006  Electro        106
# 6             2014   Latino        197
# 7             2019   Latino        197
# 8             2013      Pop        132
# 9             2000      Pop        132
# 10            2019   Latino        197
# 11            2019   Latino        197
# 12            2015    Salsa         67
# 13            2003   Latino        197
# 14            2019   Latino        197
# 15            2019   Latino        197
# 16            2003   Latino        197
# 17            2019   Latino        197
# 18            2014   Latino        197
# 19            2024   Latino        197
# 20            2020    Salsa         67
# 21            2020    Salsa         67
# 22            2020    Salsa         67
# 23            2020    Salsa         67
# 24            2020    Salsa         67
# 25            2020    Salsa         67
# 26            2011      NaN         -1
# 27            2022   Latino        197

# %%
df_artista.to_csv("celia.csv", index=False)

# %%
def conseguir_canciones(artist_name, limit=50):     # Función para conseguir 50 canciones de la artista que quieras
    url = "https://api.deezer.com/search"           # URL base de la API para buscar
    params = {                                      # Para insertar los parámetros de la búsqueda
        "q": f'artist:"{artist_name}"',             # La API busca artista por q
        "limit": limit                              # Limit sirve para que saque solo 50
    }
    try:                                            # Bloque try/excep para llamar a la API y que nos dé el resultado
        response = requests.get(url, params=params)
        if response.status_code != 200:
            print("Error en la llamada a Deezer:", response.status_code)    # Si falla lo va a informar
            return pd.DataFrame([])                                         # Y también nos va a devolver el DF vacío
        data = response.json()                                              # Si no falla da la respuesta en json
    except Error as e:
        print("Error en la llamada a Deezer:", e)                           # Para que nos diga exactamente cuál es el error
        return pd.DataFrame([])

    canciones = data.get("data", [])                # Obtiene la lista de canciones
    lista_canciones = []                            # Lista donde se van a acumular las filas para el DF final

    for cancion in canciones:                       # Bucle para que itere con todas las canciones y nos vaya dando los datos
        track_id = cancion["id"]                    # Nos da el id de la canción
        track = requests.get(f"https://api.deezer.com/track/{track_id}").json()  # Pide todos los datos que estén en track
        album = requests.get(f"https://api.deezer.com/album/{track['album']['id']}").json() # Pide todos los datos que estén en album

        genre_id = album.get("genre_id")   # Extrae el ID del género de album
        genre_name = None                  # Creamos la variable "vacía"
        if album.get("genres") and album["genres"].get("data"):   # Le decimoa que en el caso de que genres exista en album
            genre_name = album["genres"]["data"][0].get("name")   # Entonces nos diga el primer género que aparezca (por si hay varios)

        tracks_type = "colaboracion" if len(track.get("contributors", [])) > 1 else album.get("record_type", "track")
        # Buscamos colaboraciones. Para ello, si en contributor aparece más de 1, entonces se trata de una colaboración
        # Si no, le decimos que nos ponga lo que aparezca en record_type que es single o album, y si no que ponga track
        release_year = track.get("release_date", "")[:4] if track.get("release_date") else None
        # Obtiene el año de lanzamiento solo si hay 4 cifras, si no pondrá None 
        lista_canciones.append({                   # Creamos un diccionario para añadir todos los datos que necesitamos
            "id_artista": track["artist"]["id"],
            "nombre_artista": artist_name,
            "titulo_cancion": track["title"],
            "titulo_album": track["album"]["title"],
            "tipo": tracks_type,
            "año_lanzamiento": release_year,
            "genero": genre_name,
            "id_genero": genre_id,
        })

    return pd.DataFrame(lista_canciones)        # Hacemos que nos devuelta el resultado en un DF

df_artista = conseguir_canciones("Aretha Franklin", limit=50)
df_artista
# Out:
#     id_artista   nombre_artista  \
# 0         2059  Aretha_Franklin
# 1         2059  Aretha_Franklin
# 2         2059  Aretha_Franklin
# 3         2059  Aretha_Franklin
# 4         2708  Aretha_Franklin
# 5    264516192  Aretha_Franklin
# 6         2059  Aretha_Franklin
# 7         2059  Aretha_Franklin
# 8          175  Aretha_Franklin
# 9         2059  Aretha_Franklin
# 10        2059  Aretha_Franklin
# 11        2059  Aretha_Franklin
# 12        2059  Aretha_Franklin
# 13        2059  Aretha_Franklin
# 14        2059  Aretha_Franklin
# 15        2059  Aretha_Franklin
# 16        2059  Aretha_Franklin
# 17        2059  Aretha_Franklin
# 18        2059  Aretha_Franklin
# 5                           Aretha (Expanded Edition)  colaboracion
# 6                                          Soul Queen         album
# 7   A Brand New Me: Aretha Franklin (with The Roya...  colaboracion
# 8                                       Greatest Hits  colaboracion
# 9   A Brand New Me: Aretha Franklin (with The Roya...  colaboracion
# 10                                 Who's Zoomin' Who?         album
# 11                                  The Queen Of Soul         album
# 12              Who's Zoomin' Who? (Expanded Edition)         album
# 13                             Love All The Hurt Away         album
# 14                                      So Damn Happy         album
# 15                                             Aretha         album
# 16         Laughing On the Outside (Expanded Edition)         album
# 17                             A Rose Is Still A Rose         album
# 18                                  The Queen of Soul         album
# 19                                      A Bit Of Soul         album
# 20                             A Rose Is Still A Rose         album
# 21                                       Get It Right         album
# 22                                         Aretha Now         album
# 23                                 Who's Zoomin' Who?         album
# 24                                        Soul Sister         album
# 25                                        Soul Sister         album
# 26                     Rhino Hi-Five: Chart Hits: R&B            ep
# 27             I Never Loved a Man the Way I Love You         album
# 28                                  The Queen Of Soul         album
# 29  Aretha In Person with The Ray Bryant Combo (Ex...         album
# 30  Aretha In Person with The Ray Bryant Combo (Ex...         album
# 31                                              Think        single
# 32          Dance Vault Mixes - (Pride) A Deeper Love         album
# 33                                       Get It Right         album
# 34                                         Soul Queen         album
# 35            Runnin' Out of Fools (Expanded Edition)         album
# 36  A Brand New Me: Aretha Franklin (with The Roya...  colaboracion
# 37                   One Lord, One Faith, One Baptism  colaboracion
# 38  How I Got Over (Live at New Temple Missionary ...        single
# 39                                         Jump To It         album
# 40  Unforgettable: A Tribute To Dinah Washington (...         album
# 41  Aretha In Person with The Ray Bryant Combo (Ex...         album
# 42                           Take It Like You Give It         album
# 43  The Electrifying Aretha Franklin (Expanded Edi...         album
# 44  The Electrifying Aretha Franklin (Expanded Edi...         album
# 45         Laughing On the Outside (Expanded Edition)         album
# 46                            Young, Gifted and Black         album
# 47            Runnin' Out of Fools (Expanded Edition)         album
# 48                                         Soul Queen         album
# 49  The Electrifying Aretha Franklin (Expanded Edi...         album
#
#    año_lanzamiento       genero  id_genero
# 0             1995          Pop        132
# 1             2007          Pop        132
# 2             1993          Pop        132
# 3             1987          Pop        132
# 4             2011          Pop        132
# 5             1986          R&B        165
# 6             2007          Pop        132
# 7             2017          R&B        165
# 8             1991          Pop        132
# 9             2017          R&B        165
# 10            2001  Rap/Hip Hop        116
# 11            2014          R&B        165
# 12            1985          R&B        165
# 13            1981          R&B        165
# 14            2003          R&B        165
# 15            1980          R&B        165
# 16            1963          R&B        165
# 17            1998          R&B        165
# 18            2018          R&B        165
# 19            1996          R&B        165
# 20            1998          R&B        165
# 21            1983          R&B        165
# 22            1993          Pop        132
# 23            2001  Rap/Hip Hop        116
# 24            1966          R&B        165
# 25            1966          R&B        165
# 26            2006          Pop        132
# 27            1995          Pop        132
# 28            2014          R&B        165
# 29            2025          R&B        165
# 30            2025          R&B        165
# 31            2011          R&B        165
# 32            2021        Dance        113
# 33            1983          R&B        165
# 34            2007          Pop        132
# 35            1964          R&B        165
# 48       Grabaciones Completas (Remastered)         album            2018
# 49   Raíces de la Canción Española, Vol. 15         album            1997
#
#       genero  id_genero
# 0        NaN         -1
# 1        NaN         -1
# 2   Flamenco         36
# 3        NaN         -1
# 4   Flamenco         36
# 5        NaN         -1
# 6        NaN         -1
# 7   Flamenco         36
# 8   Flamenco         36
# 9   Flamenco         36
# 10  Flamenco         36
# 11  Flamenco         36
# 12      Jazz        129
# 13       Pop        132
# 14       NaN         -1
# 15  Flamenco         36
# 16       NaN         -1
# 17  Flamenco         36
# 18  Flamenco         36
# 19      Jazz        129
# 20  Flamenco         36
# 21       NaN         -1
# 22  Flamenco         36
# 23  Flamenco         36
# 24  Flamenco         36
# 25       NaN         -1
# 26       NaN         -1
# 27    Latino        197
# 28    Latino        197
# 29      Jazz        129
# 30       NaN         -1
# 31    Latino        197
# 32       NaN         -1
# 33       Pop        132
# 34       NaN         -1
# 35  Flamenco         36
# 36  Flamenco         36
# 37  Flamenco         36
# 38    Latino        197
# 39       NaN         -1
# 40  Flamenco         36
# 41  Flamenco         36
# 42  Flamenco         36
# 43    Bolero        524
# 44    Latino        197
# 45    Latino        197
# 46    Latino        197
# 47  Flamenco         36
# 48  Flamenco         36
# 49    Latino        197

# %%
df_artista.to_csv("lola.csv", index=False)

# %%
def conseguir_canciones(artist_name, limit=50):     # Función para conseguir 50 canciones de la artista que quieras
    url = "https://api.deezer.com/search"           # URL base de la API para buscar
    params = {                                      # Para insertar los parámetros de la búsqueda
        "q": f'artist:"{artist_name}"',             # La API busca artista por q
        "limit": limit                              # Limit sirve para que saque solo 50
    }
    try:                                            # Bloque try/excep para llamar a la API y que nos dé el resultado
        response = requests.get(url, params=params)
        if response.status_code != 200:
            print("Error en la llamada a Deezer:", response.status_code)    # Si falla lo va a informar
            return pd.DataFrame([])                                         # Y también nos va a devolver el DF vacío
        data = response.json()                                              # Si no falla da la respuesta en json
    except Error as e:
        print("Error en la llamada a Deezer:", e)                           # Para que nos diga exactamente cuál es el error
        return pd.DataFrame([])

    canciones = data.get("data", [])                # Obtiene la lista de canciones
    lista_canciones = []                            # Lista donde se van a acumular las filas para el DF final

    for cancion in canciones:                       # Bucle para que itere con todas las canciones y nos vaya dando los datos
        track_id = cancion["id"]                    # Nos da el id de la canción
        track = requests.get(f"https://api.deezer.com/track/{track_id}").json()  # Pide todos los datos que estén en track
        album = requests.get(f"https://api.deezer.com/album/{track['album']['id']}").json() # Pide todos los datos que estén en album

        genre_id = album.get("genre_id")   # Extrae el ID del género de album
        genre_name = None                  # Creamos la variable "vacía"
        if album.get("genres") and album["genres"].get("data"):   # Le decimoa que en el caso de que genres exista en album
            genre_name = album["genres"]["data"][0].get("name")   # Entonces nos diga el primer género que aparezca (por si hay varios)

        tracks_type = "colaboracion" if len(track.get("contributors", [])) > 1 else album.get("record_type", "track")
        # Buscamos colaboraciones. Para ello, si en contributor aparece más de 1, entonces se trata de una colaboración
        # Si no, le decimos que nos ponga lo que aparezca en record_type que es single o album, y si no que ponga track
        release_year = track.get("release_date", "")[:4] if track.get("release_date") else None
        # Obtiene el año de lanzamiento solo si hay 4 cifras, si no pondrá None 
        lista_canciones.append({                   # Creamos un diccionario para añadir todos los datos que necesitamos
            "id_artista": track["artist"]["id"],
            "nombre_artista": artist_name,
            "titulo_cancion": track["title"],
            "titulo_album": track["album"]["title"],
            "tipo": tracks_type,
            "año_lanzamiento": release_year,
            "genero": genre_name,
            "id_genero": genre_id,
        })

    return pd.DataFrame(lista_canciones)        # Hacemos que nos devuelta el resultado en un DF

df_artista = conseguir_canciones("Nina Simone", limit=50)
df_artista
# Out:
#     id_artista nombre_artista  \
# 0          744    Nina_Simone
# 1          744    Nina_Simone
# 2          744    Nina_Simone
# 3          744    Nina_Simone
# 4          744    Nina_Simone
# 5          744    Nina_Simone
# 6          744    Nina_Simone
# 7          744    Nina_Simone
# 8          744    Nina_Simone
# 9          744    Nina_Simone
# 10         744    Nina_Simone
# 11         744    Nina_Simone
# 12         744    Nina_Simone
# 13         744    Nina_Simone
# 14         744    Nina_Simone
# 15         744    Nina_Simone
# 16         744    Nina_Simone
# 17         744    Nina_Simone
# 18         744    Nina_Simone
# 19         744    Nina_Simone
# 20         744    Nina_Simone
# 21         744    Nina_Simone
# 22         744    Nina_Simone
# 23         744    Nina_Simone
# 24         744    Nina_Simone
# 25         744    Nina_Simone
# 26         744    Nina_Simone
# 27         744    Nina_Simone
# 28         744    Nina_Simone
# 29         744    Nina_Simone
# 30         744    Nina_Simone
# 31         744    Nina_Simone
# 32         744    Nina_Simone
# 33         744    Nina_Simone
# 34         744    Nina_Simone
# 35         744    Nina_Simone
# 36         744    Nina_Simone
# 37         744    Nina_Simone
# 38         744    Nina_Simone
# 39         744    Nina_Simone
# 40         744    Nina_Simone
# 41         744    Nina_Simone
# 42         744    Nina_Simone
# 43         744    Nina_Simone
# 44         744    Nina_Simone
# 45         744    Nina_Simone
# 46         744    Nina_Simone
# 47         744    Nina_Simone
# 48         744    Nina_Simone
# 49         744    Nina_Simone
#
#                                        titulo_cancion  \
# 0                                I Put A Spell On You
# 1                                        Feeling Good
# 2   Ain't Got No - I Got Life (From the Musical Pr...
# 3                                           Sinnerman
# 4                           My Baby Just Cares for Me
# 5                       Sinnerman (Sofi Tukker Remix)
# 6                                       Mr. Bojangles
# 35                                  The Greatest Hits         album
# 36                                  The Greatest Hits         album
# 37                                  The Greatest Hits         album
# 38                                  The Greatest Hits         album
# 39                                  The Greatest Hits         album
# 40                                  The Greatest Hits         album
# 41                                  Nina with Strings         album
# 42                                  The Greatest Hits         album
# 43  The Very Best Of Nina Simone 1967-1972 - Sugar...         album
# 44                      Don't Let Me Be Misunderstood         album
# 45                           Nina Simone at Town Hall         album
# 46     Four Women: The Nina Simone Philips Recordings         album
# 47            My Baby Just Cares For Me (HONNE Remix)  colaboracion
# 48                                 Fodder On My Wings         album
# 49                                   New World Coming         album
#
#    año_lanzamiento   genero  id_genero
# 0             2018     Jazz        129
# 1             2019     Jazz        129
# 2             2003      Pop        132
# 3             2019     Jazz        129
# 4             2009     Jazz        129
# 5             2021     Jazz        129
# 6             2003      Pop        132
# 7             1998     Jazz        129
# 8             2026  Electro        106
# 9             2018     Jazz        129
# 10            2006     Jazz        129
# 11            2012     Jazz        129
# 12            2006     Jazz        129
# 13            2003      Pop        132
# 14            2003      Pop        132
# 15            2003      Pop        132
# 16            1995     Jazz        129
# 17            2003      Pop        132
# 18            1969     Jazz        129
# 19            2003      Pop        132
# 20            2018     Jazz        129
# 21            2003      Pop        132
# 22            2003      Pop        132
# 23            2003      Pop        132
# 24            2003      Pop        132
# 25            1998     Jazz        129
# 26            2018     Jazz        129
# 27            2003      Pop        132
# 28            2003      Pop        132
# 29            1992     Jazz        129
# 30            2018     Jazz        129
# 31            2021     Jazz        129
# 32            2020     Jazz        129
# 33            2018     Jazz        129
# 34            1998     Jazz        129
# 35            2003      Pop        132
# 36            2003      Pop        132
# 37            2003      Pop        132
# 38            2003      Pop        132
# 39            2003      Pop        132
# 40            2003      Pop        132
# 41            2005     Jazz        129
# 42            2003      Pop        132
# 43            1998     Jazz        129
# 44            2018     Jazz        129
# 45            2005     Jazz        129
# 46            2018     Jazz        129
# 47            2022     Jazz        129
# 48            2020     Jazz        129
# 49            2020     Jazz        129

# %%
df_artista.to_csv("nina.csv", index=False)

# %%
def conseguir_canciones(artist_name, limit=50):     # Función para conseguir 50 canciones de la artista que quieras
    url = "https://api.deezer.com/search"           # URL base de la API para buscar
    params = {                                      # Para insertar los parámetros de la búsqueda
        "q": f'artist:"{artist_name}"',             # La API busca artista por q
        "limit": limit                              # Limit sirve para que saque solo 50
    }
    try:                                            # Bloque try/excep para llamar a la API y que nos dé el resultado
        response = requests.get(url, params=params)
        if response.status_code != 200:
            print("Error en la llamada a Deezer:", response.status_code)    # Si falla lo va a informar
            return pd.DataFrame([])                                         # Y también nos va a devolver el DF vacío
        data = response.json()                                              # Si no falla da la respuesta en json
    except Error as e:
        print("Error en la llamada a Deezer:", e)                           # Para que nos diga exactamente cuál es el error
        return pd.DataFrame([])

    canciones = data.get("data", [])                # Obtiene la lista de canciones
    lista_canciones = []                            # Lista donde se van a acumular las filas para el DF final

    for cancion in canciones:                       # Bucle para que itere con todas las canciones y nos vaya dando los datos
        track_id = cancion["id"]                    # Nos da el id de la canción
        track = requests.get(f"https://api.deezer.com/track/{track_id}").json()  # Pide todos los datos que estén en track
        album = requests.get(f"https://api.deezer.com/album/{track['album']['id']}").json() # Pide todos los datos que estén en album

        genre_id = album.get("genre_id")   # Extrae el ID del género de album
        genre_name = None                  # Creamos la variable "vacía"
        if album.get("genres") and album["genres"].get("data"):   # Le decimoa que en el caso de que genres exista en album
            genre_name = album["genres"]["data"][0].get("name")   # Entonces nos diga el primer género que aparezca (por si hay varios)

        tracks_type = "colaboracion" if len(track.get("contributors", [])) > 1 else album.get("record_type", "track")
        # Buscamos colaboraciones. Para ello, si en contributor aparece más de 1, entonces se trata de una colaboración
        # Si no, le decimos que nos ponga lo que aparezca en record_type que es single o album, y si no que ponga track
        release_year = track.get("release_date", "")[:4] if track.get("release_date") else None
        # Obtiene el año de lanzamiento solo si hay 4 cifras, si no pondrá None 
        lista_canciones.append({                   # Creamos un diccionario para añadir todos los datos que necesitamos
            "id_artista": track["artist"]["id"],
            "nombre_artista": artist_name,
            "titulo_cancion": track["title"],
            "titulo_album": track["album"]["title"],
            "tipo": tracks_type,
            "año_lanzamiento": release_year,
            "genero": genre_name,
            "id_genero": genre_id,
        })

    return pd.DataFrame(lista_canciones)        # Hacemos que nos devuelta el resultado en un DF

df_artista = conseguir_canciones("Sylvie Vartan", limit=50)
df_artista
# Out:
#     id_artista nombre_artista  \
# 0        11440  Sylvie_Vartan
# 1        11440  Sylvie_Vartan
# 2     13314683  Sylvie_Vartan
# 3         1060  Sylvie_Vartan
# 4        11440  Sylvie_Vartan
# 5        11440  Sylvie_Vartan
# 6        11440  Sylvie_Vartan
# 7        11440  Sylvie_Vartan
# 8        11440  Sylvie_Vartan
# 9        11440  Sylvie_Vartan
# 10        4509  Sylvie_Vartan
# 11       11440  Sylvie_Vartan
# 12       11440  Sylvie_Vartan
# 13       11440  Sylvie_Vartan
# 14       11440  Sylvie_Vartan
# 15       11440  Sylvie_Vartan
# 16       11440  Sylvie_Vartan
# 17        1060  Sylvie_Vartan
# 18       11440  Sylvie_Vartan
# 19       11440  Sylvie_Vartan
# 20       11440  Sylvie_Vartan
# 21       11440  Sylvie_Vartan
# 22       11440  Sylvie_Vartan
# 23       11440  Sylvie_Vartan
# 24       11440  Sylvie_Vartan
# 25       11440  Sylvie_Vartan
# 26       11440  Sylvie_Vartan
# 27       11440  Sylvie_Vartan
# 28       11440  Sylvie_Vartan
# 29       11440  Sylvie_Vartan
# 30       11440  Sylvie_Vartan
# 31       11440  Sylvie_Vartan
# 32       11440  Sylvie_Vartan
# 33       11440  Sylvie_Vartan
# 34       11440  Sylvie_Vartan
# 35       11440  Sylvie_Vartan
# 36       11440  Sylvie_Vartan
# 37       11440  Sylvie_Vartan
# 38       11440  Sylvie_Vartan
# 39       11440  Sylvie_Vartan
# 40       11440  Sylvie_Vartan
# 41       11440  Sylvie_Vartan
# 42       11440  Sylvie_Vartan
# 43       11440  Sylvie_Vartan
# 44       11440  Sylvie_Vartan
# 45       11440  Sylvie_Vartan
# 46       11440  Sylvie_Vartan
# 47       11440  Sylvie_Vartan
#
#                                        titulo_cancion  \
# 0                                          La Maritza
# 1                                     Comme un garçon
# 2                                     Baby c'est vous
# 3                                    J'ai un problème
# 4                                        Si je chante
# 5                   L'amour c'est comme une cigarette
# 6                               Est-Ce Que Tu Le Sais
# 7                                     Panne D'essence
# 8                                          La Maritza
# 9                                      Sang pour sang
# 10                    La première fois qu'on s'aimera
# 11                    La plus belle pour aller danser
# 12                                     Ne t'en va pas
# 13                  L'amour c'est comme une cigarette
# 14                                            Nicolas
# 15               La Maritza (Extended Andréas Rework)
# 16                            Ballade pour un sourire
# 17  L'hymne à l'amour / Non, je ne regrette rien (...
# 18                                   Irrésistiblement
# 19                               En écoutant la pluie
# 20                    La plus belle pour aller danser
# 21                       Georges (George Disco Tango)
# 22                                              Aimer
# 23               Chanson de l'autruche (Version edit)
# 24                       La drôle de fin (Last Tango)
# 25                               Par amour, par pitié
# 26                                      Toi le garçon
# 27                                            Déprime
# 28                               Merci pour le regard
# 29                                         Toi jamais
# 30              Petit rainbow (Summer Love Sensation)
# 31                               En écoutant la pluie
# 32  Qu'est ce qui fait pleurer les blondes (Ride t...
# 33                                    Comme un garçon
# 34                                   L'Orient-Express
# 35       La Maritza (Andréas Rework) (Andréas Rework)
# 36                           Je chante encore l'amour
# 37                             Due minuti di felicità
# 38                                    Baby C'est Vous
# 39                                    2'35 de bonheur
# 40  Les moulins de mon coeur (The Windmills of You...
# 41                                   Tous Mes Copains
# 42                                            Nicolas
# 43                                    La drôle de fin
# 44                                       Danse ta vie
# 45                                Bye Bye Leroy Brown
# 46                              La musique que j'aime
# 47                    L'amour c'est comme les bateaux
#
#                                titulo_album          tipo año_lanzamiento  \
# 0                                La Maritza         album            2026
# 1                Le meilleur des années RCA         album            2026
# 2                                   Rivages  colaboracion            2024
# 3                                Best Of 70  colaboracion            2014
# 4                                    Exodus            ep            2017
# 5                        Une vie en musique         album            2015
# 6                     Est-Ce Que Tu Le Sais        single            2010
# 7                     Est-Ce Que Tu Le Sais  colaboracion            2010
# 8                             Sylvie Vartan         album            1995
# 9                               Avec toi...         album            2018
# 10                            Les années 30  colaboracion            2018
# 11          La plus belle pour aller danser            ep            2026
# 12                         Twiste et chante         album            2026
# 13               Le meilleur des années RCA         album            2026
# 14                            Déraisonnable         album            2026
# 15     La Maritza (Extended Andréas Rework)        single            2026
# 16                  Les années RCA (Vol. 2)         album            2026
# 17                              Sylvie Live  colaboracion            2010
# 18                  Les années RCA (Vol. 3)         album            2026
# 19                           Triple Best Of         album            2026
# 20                            Sylvie Vartan         album            1995
# 21                                  Georges         album            2026
# 22                           Triple Best Of         album            2026
# 23         Emilie Jolie (Version originale)         album            2021
# 24  Qu'est ce qui fait pleurer les blondes?         album            2026
# 25                 Sylvie (2'35 de bonheur)         album            2026
# 26               Le meilleur des années RCA         album            2026
# 27                             Danse ta vie         album            2026
# 28                     Merci pour le regard        single            2021
# 29  Qu'est ce qui fait pleurer les blondes?         album            2026
# 30                                  Georges         album            2026
# 31                       Une vie en musique         album            2015
# 32                           Triple Best Of         album            2026
# 33                       Une vie en musique         album            2015
# 34                       Une vie en musique         album            2015
# 35              La Maritza (Andréas Rework)        single            2026
# 36                                Fantaisie         album            2026
# 37                              Se io canto         album            2026
# 38                                   Sylvie         album            1962
# 39                 Sylvie (2'35 de bonheur)         album            2026
# 40                         La reine de Saba         album            2026
# 41                       La Panne D'essence        single            2014
# 42                       Une vie en musique         album            2015
# 43                       Une vie en musique         album            2015
# 44                           Triple Best Of         album            2026
# 45                       Une vie en musique         album            2015
# 46                              Avec toi...         album            2018
# 47                   Ta sorcière bien-aimée         album            2026
#
#      genero  id_genero
# 0       Pop        132
# 1       Pop        132
# 2   Electro        106
# 3       Pop        132
# 4       NaN         -1
# 5       NaN         -1
# 6       Pop        132
# 7       Pop        132
# 8       Pop        132
# 9       NaN         -1
# 10      Pop        132
# 11      Pop        132
# 12      Pop        132
# 13      Pop        132
# 14      Pop        132
# 15      Pop        132
# 16      Pop        132
# 17      NaN         -1
# 18      Pop        132
# 19      Pop        132
# 20      Pop        132
# 21      Pop        132
# 22      Pop        132
# 23      NaN         -1
# 24      Pop        132
# 25      Pop        132
# 26      Pop        132
# 27      Pop        132
# 28      Pop        132
# 29      Pop        132
# 30      Pop        132
# 31      NaN         -1
# 32      Pop        132
# 33      NaN         -1
# 34      NaN         -1
# 35      Pop        132
# 36      Pop        132
# 37      Pop        132
# 38      Pop        132
# 39      Pop        132
# 40      Pop        132
# 41      NaN         -1
# 42      NaN         -1
# 43      NaN         -1
# 44      Pop        132
# 45      NaN         -1
# 46      NaN         -1
# 47      Pop        132

# %%
df_artista.to_csv("silvie.csv", index=False)

# %%
def conseguir_canciones(artist_name, limit=50):     # Función para conseguir 50 canciones de la artista que quieras
    url = "https://api.deezer.com/search"           # URL base de la API para buscar
    params = {                                      # Para insertar los parámetros de la búsqueda
        "q": f'artist:"{artist_name}"',             # La API busca artista por q
        "limit": limit                              # Limit sirve para que saque solo 50
    }
    try:                                            # Bloque try/excep para llamar a la API y que nos dé el resultado
        response = requests.get(url, params=params)
        if response.status_code != 200:
            print("Error en la llamada a Deezer:", response.status_code)    # Si falla lo va a informar
            return pd.DataFrame([])                                         # Y también nos va a devolver el DF vacío
        data = response.json()                                              # Si no falla da la respuesta en json
    except Error as e:
        print("Error en la llamada a Deezer:", e)                           # Para que nos diga exactamente cuál es el error
        return pd.DataFrame([])

    canciones = data.get("data", [])                # Obtiene la lista de canciones
    lista_canciones = []                            # Lista donde se van a acumular las filas para el DF final

    for cancion in canciones:                       # Bucle para que itere con todas las canciones y nos vaya dando los datos
        track_id = cancion["id"]                    # Nos da el id de la canción
        track = requests.get(f"https://api.deezer.com/track/{track_id}").json()  # Pide todos los datos que estén en track
        album = requests.get(f"https://api.deezer.com/album/{track['album']['id']}").json() # Pide todos los datos que estén en album

        genre_id = album.get("genre_id")   # Extrae el ID del género de album
        genre_name = None                  # Creamos la variable "vacía"
        if album.get("genres") and album["genres"].get("data"):   # Le decimoa que en el caso de que genres exista en album
            genre_name = album["genres"]["data"][0].get("name")   # Entonces nos diga el primer género que aparezca (por si hay varios)

        tracks_type = "colaboracion" if len(track.get("contributors", [])) > 1 else album.get("record_type", "track")
        # Buscamos colaboraciones. Para ello, si en contributor aparece más de 1, entonces se trata de una colaboración
        # Si no, le decimos que nos ponga lo que aparezca en record_type que es single o album, y si no que ponga track
        release_year = track.get("release_date", "")[:4] if track.get("release_date") else None
        # Obtiene el año de lanzamiento solo si hay 4 cifras, si no pondrá None 
        lista_canciones.append({                   # Creamos un diccionario para añadir todos los datos que necesitamos
            "id_artista": track["artist"]["id"],
            "nombre_artista": artist_name,
            "titulo_cancion": track["title"],
            "titulo_album": track["album"]["title"],
            "tipo": tracks_type,
            "año_lanzamiento": release_year,
            "genero": genre_name,
            "id_genero": genre_id,
        })

    return pd.DataFrame(lista_canciones)        # Hacemos que nos devuelta el resultado en un DF

df_artista = conseguir_canciones("Patty Pravo", limit=50)
df_artista
# Out:
#     id_artista nombre_artista                      titulo_cancion  \
# 0        58615    Patty_Pravo                          La bambola
# 1        58615    Patty_Pravo                   Pensiero stupendo
# 2        58615    Patty_Pravo                          La bambola
# 3        58615    Patty_Pravo                      Ragazzo Triste
# 4        58615    Patty_Pravo                         Il paradiso
# 5        58615    Patty_Pravo  Un po' come la vita (Sanremo 2019)
# 6        58615    Patty_Pravo                         Tutt'al più
# 7        58615    Patty_Pravo                          Pazza idea
# 8        58615    Patty_Pravo             Nel giardino dell'amore
# 22                                    Bambola  colaboracion            2017
# 23                        Best of Patty Pravo         album            2013
# 24                           The Lost Records         album            2012
# 25                             Patty Live '99         album            2001
# 26                           Di Vero In Fondo         album            2008
# 27       Mine Vaganti - international version         album            2010
# 28                                      Opera        single            2026
# 29                      Notti, guai e libertà         album            1998
# 30                                Patty Pravo         album            2000
# 31                                    Bambola  colaboracion            2017
# 32                         Patty Pravo (Live)         album            2013
# 33  Il Meglio Di Patty Pravo: Grandi Successi         album            2016
# 34                       Live Arena Di Verona         album            2013
# 35                       Live Arena Di Verona         album            2013
# 36                       Live Arena Di Verona         album            2013
# 37                       Live Arena Di Verona         album            2013
# 38                                 Super Best         album            2012
# 39                      Ti lascio una canzone        single            2026
# 40                       Live Arena Di Verona         album            2013
# 41                        Best of Patty Pravo         album            2013
# 42                      Notti, guai e libertà         album            1998
# 43                                Patty Pravo         album            2000
# 44                   Nella terra dei pinguini         album            2011
# 45                        Dig'Hits All Italie         album            2006
# 46                                Patty Pravo         album            2000
# 47                                Patty Pravo         album            2000
# 48                                Patty Pravo         album            2002
# 49                                Patty Pravo         album            2002
#
#      genero  id_genero
# 0       Pop        132
# 1       Pop        132
# 2       Pop        132
# 3       Pop        132
# 4       Pop        132
# 5       Pop        132
# 6       Pop        132
# 7       Pop        132
# 8       Pop        132
# 9       Pop        132
# 10      Pop        132
# 11      Pop        132
# 12      Pop        132
# 13    Dance        113
# 14  Electro        106
# 15      Pop        132
# 16      NaN         -1
# 17      NaN         -1
# 18      Pop        132
# 19      Pop        132
# 20      Pop        132
# 21      Pop        132
# 22  Electro        106
# 23      Pop        132
# 24      NaN         -1
# 25      Pop        132
# 26      Pop        132
# 27      Pop        132
# 28      Pop        132
# 29      Pop        132
# 30      Pop        132
# 31  Electro        106
# 32      Pop        132
# 33      Pop        132
# 34      Pop        132
# 35      Pop        132
# 36      Pop        132
# 37      Pop        132
# 38      NaN         -1
# 39      Pop        132
# 40      Pop        132
# 41      Pop        132
# 42      Pop        132
# 43      Pop        132
# 44      Pop        132
# 45      NaN         -1
# 46      Pop        132
# 47      Pop        132
# 48      Pop        132
# 49      Pop        132

# %%
df_artista.to_csv("patty.csv", index=False)

# %%
def conseguir_canciones(artist_name, limit=50):     # Función para conseguir 50 canciones de la artista que quieras
    url = "https://api.deezer.com/search"           # URL base de la API para buscar
    params = {                                      # Para insertar los parámetros de la búsqueda
        "q": f'artist:"{artist_name}"',             # La API busca artista por q
        "limit": limit                              # Limit sirve para que saque solo 50
    }
    try:                                            # Bloque try/excep para llamar a la API y que nos dé el resultado
        response = requests.get(url, params=params)
        if response.status_code != 200:
            print("Error en la llamada a Deezer:", response.status_code)    # Si falla lo va a informar
            return pd.DataFrame([])                                         # Y también nos va a devolver el DF vacío
        data = response.json()                                              # Si no falla da la respuesta en json
    except Error as e:
        print("Error en la llamada a Deezer:", e)                           # Para que nos diga exactamente cuál es el error
        return pd.DataFrame([])

    canciones = data.get("data", [])                # Obtiene la lista de canciones
    lista_canciones = []                            # Lista donde se van a acumular las filas para el DF final

    for cancion in canciones:                       # Bucle para que itere con todas las canciones y nos vaya dando los datos
        track_id = cancion["id"]                    # Nos da el id de la canción
        track = requests.get(f"https://api.deezer.com/track/{track_id}").json()  # Pide todos los datos que estén en track
        album = requests.get(f"https://api.deezer.com/album/{track['album']['id']}").json() # Pide todos los datos que estén en album

        genre_id = album.get("genre_id")   # Extrae el ID del género de album
        genre_name = None                  # Creamos la variable "vacía"
        if album.get("genres") and album["genres"].get("data"):   # Le decimoa que en el caso de que genres exista en album
            genre_name = album["genres"]["data"][0].get("name")   # Entonces nos diga el primer género que aparezca (por si hay varios)

        tracks_type = "colaboracion" if len(track.get("contributors", [])) > 1 else album.get("record_type", "track")
        # Buscamos colaboraciones. Para ello, si en contributor aparece más de 1, entonces se trata de una colaboración
        # Si no, le decimos que nos ponga lo que aparezca en record_type que es single o album, y si no que ponga track
        release_year = track.get("release_date", "")[:4] if track.get("release_date") else None
        # Obtiene el año de lanzamiento solo si hay 4 cifras, si no pondrá None 
        lista_canciones.append({                   # Creamos un diccionario para añadir todos los datos que necesitamos
            "id_artista": track["artist"]["id"],
            "nombre_artista": artist_name,
            "titulo_cancion": track["title"],
            "titulo_album": track["album"]["title"],
            "tipo": tracks_type,
            "año_lanzamiento": release_year,
            "genero": genre_name,
            "id_genero": genre_id,
        })

    return pd.DataFrame(lista_canciones)        # Hacemos que nos devuelta el resultado en un DF

df_artista = conseguir_canciones("Rita Pavone", limit=50)
df_artista
# Out:
#     id_artista nombre_artista                      titulo_cancion  \
# 0        77224    Rita_Pavone          Viva la pappa col pomodoro
# 1        77224    Rita_Pavone                Il ballo del mattone
# 2        77224    Rita_Pavone                               Cuore
# 3        77224    Rita_Pavone                            Zucchero
# 4        77224    Rita_Pavone             Che m'importa del mondo
# 5        77224    Rita_Pavone                               Cuore
# 6        77224    Rita_Pavone            Solo tu (vers. Catalana)
# 7        77224    Rita_Pavone               Plip (vers. Catalana)
# 8        77224    Rita_Pavone                        Alla Mia Età
# 9        77224    Rita_Pavone             Que Me Importa el Mundo
# 10       77224    Rita_Pavone                          Il geghegè
# 11       77224    Rita_Pavone                  Datemi un martello
# 12       77224    Rita_Pavone                             Corazon
# 13       77224    Rita_Pavone              Come Te Non Ce'Nessuno
# 27  Rita Pavone canta en Espanol (Singles Collection)         album
# 28  Rita Pavone canta en Espanol (Singles Collection)         album
# 29                                 31 Grandi Successi         album
# 30                                 31 Grandi Successi         album
# 31                                 31 Grandi Successi         album
# 32  Rita Pavone canta en Espanol (Singles Collection)         album
# 33       Il geghegè e altri successi (Flashback 2011)         album
# 34                                        Rita Pavone         album
# 35               Rita Pavone - I Miei Grandi Successi         album
# 36                                 31 Grandi Successi         album
# 37                                  Ihre größten Hits         album
# 38                                  Ihre größten Hits         album
# 39                                        Rita Pavone         album
# 40                                              Cuore         album
# 41                                              Cuore         album
# 42                                              Cuore         album
# 43                             1970 Recording Session         album
# 44                                 31 Grandi Successi         album
# 45                                 31 Grandi Successi         album
# 46                                 31 Grandi Successi         album
# 47                                 31 Grandi Successi         album
# 48                                 31 Grandi Successi         album
# 49                                 31 Grandi Successi         album
#
#    año_lanzamiento genero  id_genero
# 0             1998    Pop        132
# 1             2026    Pop        132
# 2             2016    Pop        132
# 3             1996    Pop        132
# 4             2016    Pop        132
# 5             2026    Pop        132
# 6             2026    Pop        132
# 7             2026    Pop        132
# 8             2018    NaN         -1
# 9             2026    Pop        132
# 10            2016    Pop        132
# 11            2016    Pop        132
# 12            1961    Pop        132
# 13            2017   Rock        152
# 14            2000    Pop        132
# 15            2017    Pop        132
# 16            2016    Pop        132
# 17            2026    Pop        132
# 18            2026    Pop        132
# 19            2020    Pop        132
# 20            1961    Pop        132
# 21            2026    Pop        132
# 22            2016    Pop        132
# 23            2000    Pop        132
# 24            1961    Pop        132
# 25            2020    Pop        132
# 26            2015    NaN         -1
# 27            2000    Pop        132
# 28            2000    Pop        132
# 29            2016    Pop        132
# 30            2016    Pop        132
# 31            2016    Pop        132
# 32            2000    Pop        132
# 33            2026    Pop        132
# 34            2026    Pop        132
# 35            2024    Pop        132
# 36            2016    Pop        132
# 37            2026    Pop        132
# 38            2026    Pop        132
# 39            2015    Pop        132
# 40            2015    NaN         -1
# 41            2015    NaN         -1
# 42            2015    NaN         -1
# 43            1970    Pop        132
# 44            2016    Pop        132
# 45            2016    Pop        132
# 46            2016    Pop        132
# 47            2016    Pop        132
# 48            2016    Pop        132
# 49            2016    Pop        132

# %%
df_artista.to_csv("rita.csv", index=False)

# %%
def conseguir_canciones(artist_name, limit=50):     # Función para conseguir 50 canciones de la artista que quieras
    url = "https://api.deezer.com/search"           # URL base de la API para buscar
    params = {                                      # Para insertar los parámetros de la búsqueda
        "q": f'artist:"{artist_name}"',             # La API busca artista por q
        "limit": limit                              # Limit sirve para que saque solo 50
    }
    try:                                            # Bloque try/excep para llamar a la API y que nos dé el resultado
        response = requests.get(url, params=params)
        if response.status_code != 200:
            print("Error en la llamada a Deezer:", response.status_code)    # Si falla lo va a informar
            return pd.DataFrame([])                                         # Y también nos va a devolver el DF vacío
        data = response.json()                                              # Si no falla da la respuesta en json
    except Error as e:
        print("Error en la llamada a Deezer:", e)                           # Para que nos diga exactamente cuál es el error
        return pd.DataFrame([])

    canciones = data.get("data", [])                # Obtiene la lista de canciones
    lista_canciones = []                            # Lista donde se van a acumular las filas para el DF final

    for cancion in canciones:                       # Bucle para que itere con todas las canciones y nos vaya dando los datos
        track_id = cancion["id"]                    # Nos da el id de la canción
        track = requests.get(f"https://api.deezer.com/track/{track_id}").json()  # Pide todos los datos que estén en track
        album = requests.get(f"https://api.deezer.com/album/{track['album']['id']}").json() # Pide todos los datos que estén en album

        genre_id = album.get("genre_id")   # Extrae el ID del género de album
        genre_name = None                  # Creamos la variable "vacía"
        if album.get("genres") and album["genres"].get("data"):   # Le decimoa que en el caso de que genres exista en album
            genre_name = album["genres"]["data"][0].get("name")   # Entonces nos diga el primer género que aparezca (por si hay varios)

        tracks_type = "colaboracion" if len(track.get("contributors", [])) > 1 else album.get("record_type", "track")
        # Buscamos colaboraciones. Para ello, si en contributor aparece más de 1, entonces se trata de una colaboración
        # Si no, le decimos que nos ponga lo que aparezca en record_type que es single o album, y si no que ponga track
        release_year = track.get("release_date", "")[:4] if track.get("release_date") else None
        # Obtiene el año de lanzamiento solo si hay 4 cifras, si no pondrá None 
        lista_canciones.append({                   # Creamos un diccionario para añadir todos los datos que necesitamos
            "id_artista": 85766522,
            "nombre_artista": artist_name,
            "titulo_cancion": track["title"],
            "titulo_album": track["album"]["title"],
            "tipo": tracks_type,
            "año_lanzamiento": release_year,
            "genero": genre_name,
            "id_genero": genre_id,
        })

    return pd.DataFrame(lista_canciones)        # Hacemos que nos devuelta el resultado en un DF

df_artista = conseguir_canciones("Karina", limit=50)
df_artista
# Out:
#     id_artista nombre_artista  \
# 0     85766522         Karina
# 1     85766522         Karina
# 2     85766522         Karina
# 3     85766522         Karina
# 4     85766522         Karina
# 5     85766522         Karina
# 6     85766522         Karina
# 7     85766522         Karina
# 8     85766522         Karina
# 9     85766522         Karina
# 10    85766522         Karina
# 11    85766522         Karina
# 12    85766522         Karina
# 13    85766522         Karina
# 14    85766522         Karina
# 15    85766522         Karina
# 16    85766522         Karina
# 17    85766522         Karina
# 18    85766522         Karina
# 19    85766522         Karina
# 20    85766522         Karina
# 21    85766522         Karina
# 22    85766522         Karina
# 23    85766522         Karina
# 24    85766522         Karina
# 25    85766522         Karina
# 26    85766522         Karina
# 27    85766522         Karina
# 28    85766522         Karina
# 29    85766522         Karina
# 30    85766522         Karina
# 31    85766522         Karina
# 32    85766522         Karina
# 33    85766522         Karina
# 34    85766522         Karina
# 35    85766522         Karina
# 36    85766522         Karina
# 37    85766522         Karina
# 38    85766522         Karina
# 39    85766522         Karina
# 40    85766522         Karina
# 41    85766522         Karina
# 42    85766522         Karina
# 43    85766522         Karina
# 44    85766522         Karina
# 45    85766522         Karina
# 46    85766522         Karina
# 47    85766522         Karina
# 48    85766522         Karina
#
#                                        titulo_cancion  \
# 0                                       Otoño Porteño
# 1                                    Jacinto Chiclana
# 2                           Milonga de la Anunciaciòn
# 3                                              LADRON
# 4   El baúl de los recuerdos (2015 Remastered Vers...
# 5                                          Satisfeito
# 6                                 Con la Misma Moneda
# 7                                       cold and lost
# 8                                             Díganle
# 9                                              Banana
# 10                                      Sé Cómo Duele
# 11                 Inocente (En Vivo en el Luna Park)
# 12                                           Nos Dois
# 13                   SINVERGÜENZA - con Angela Torres
# 14                                            Paisaje
# 15  Show Me Love feat. Karina Chavez (Safari Radio...
# 16                                              我只需要你
# 17                                            我的全部都是你
# 18                                              你让我完整
# 19                                               我的唯一
# 20                                              你就是全部
# 21                                      Nervio Óptico
# 22                                            ADORADO
# 23    Você Ganhou de Mim / Chorando Se Foi / Lambamor
# 24                        Mami no Quiere (Radio Edit)
# 25                   Gracias Y Te Quiero (Radio Edit)
# 26                                Scream (Radio Edit)
# 27                                 Doors (Radio Edit)
# 28                                   Don't Lie A Down
# 29                          Bout to Blow (Radio Edit)
# 30                                         ¡Oh! Carol
# 31                           El Baúl de los Recuerdos
# 32                                             Bombon
# 33                                           New Song
# 34                                      Sin Vergüenza
# 35  A quién le importa (Latin Pride Version by Jua...
# 36                                     VUELVES TRISTE
# 37                                              TO-TO
# 38           I'm Today (Nefer Song) (Spanish Version)
# 39                                           No sabes
# 40                                             Heaven
# 41                                   Whispers of Owls
# 42                                            Secreto
# 43                                  Corazon Mentiroso
# 44                             Marions-nous au soleil
# 45                                 No Me Digas Que No
# 46  Sous le soleil exactement (Bande originale de ...
# 47                             I'm Today (Nefer Song)
# 48                                  Paisaje (En Vivo)
#
#                                          titulo_album          tipo  \
# 0         Musica Porteña, Il Tango di Astor Piazzolla  colaboracion
# 1         Musica Porteña, Il Tango di Astor Piazzolla  colaboracion
# 2         Musica Porteña, Il Tango di Astor Piazzolla  colaboracion
# 3                                              LADRON  colaboracion
# 4   Éxitos de 1970. Artistas Originales (Remastere...         album
# 5                               Universo Ao Meu Redor         album
# 6                                 Con la Misma Moneda         album
# 7                                       cold and lost        single
# 8                                 Con la Misma Moneda         album
# 9                                              Banana  colaboracion
# 10                            Serie 32 Grandes Éxitos         album
# 11                 Inocente (En Vivo en el Luna Park)  colaboracion
# 12                                            Saudade  colaboracion
# 13                   SINVERGÜENZA - con Angela Torres  colaboracion
# 14                                            Paisaje  colaboracion
# 15                                       Show Me Love  colaboracion
# 16                                             你是我的一切         album
# 17                                             你是我的一切         album
# 18                                             你是我的一切         album
# 19                                             你是我的一切         album
# 20                                             你是我的一切         album
# 21                                      Nervio Óptico        single
# 22                                            ADORADO        single
# 23    Você Ganhou de Mim / Chorando Se Foi / Lambamor        single
# 24                        Mami no Quiere (Radio Edit)        single
# 25                             Aquí Estoy... I'm Here         album
# 26                             Aquí Estoy... I'm Here         album
# 27                             Aquí Estoy... I'm Here         album
# 28                             Aquí Estoy... I'm Here         album
# 29                             Aquí Estoy... I'm Here         album
# 30                                     Grandes Exitos         album
# 31        El Baúl de los Recuerdos y todos sus Exitos         album
# 32                                             Bombon  colaboracion
# 33       Mummies (Original Motion Picture Soundtrack)  colaboracion
# 34                                      Sin Vergüenza         album
# 35                                 A quién le importa  colaboracion
# 36                                            QUIMERA  colaboracion
# 37                                              TO-TO  colaboracion
# 38       Mummies (Original Motion Picture Soundtrack)  colaboracion
# 39                                           No sabes  colaboracion
# 40                                            Best Of  colaboracion
# 41           Polar Park (Bande originale de la série)  colaboracion
# 42                                            Secreto        single
# 43                                      Sin Vergüenza         album
# 44                                    La belle étoile  colaboracion
# 45                                 No Me Digas Que No  colaboracion
# 46                                           BOF Anna         album
# 47       Mummies (Original Motion Picture Soundtrack)  colaboracion
# 48                                   ODISEA (En Vivo)  colaboracion
#
#    año_lanzamiento            genero  id_genero
# 0             2012             Tango         73
# 1             2012             Tango         73
# 2             2012             Tango         73
# 3             2025            Latino        197
# 4             2015               Pop        132
# 5             2006  Música Brasileña         75
# 6             2010               NaN         -1
# 7             2026           Electro        106
# 8             2010               NaN         -1
# 9             2025            Latino        197
# 10            2022            Latino        197
# 11            2022            Latino        197
# 12            2022           Electro        106
# 13            2023            Latino        197
# 14            2021            Latino        197
# 15            2007           Electro        106
# 16            2026               R&B        165
# 17            2026               R&B        165
# 18            2026               R&B        165
# 19            2026               R&B        165
# 20            2026               R&B        165
# 21            2026       Alternativo         85
# 22            2026              Folk        466
# 23            2026  Música Brasileña         75
# 24            2026            Latino        197
# 25            2026               R&B        165
# 26            2026               R&B        165
# 27            2026               R&B        165
# 28            2026               R&B        165
# 29            2026               R&B        165
# 30            2003               Pop        132
# 31            1989               Pop        132
# 32            2024               Pop        132
# 33            2023  Películas/Juegos        173
# 34            2009            Latino        197
# 35            2023               Pop        132
# 36            2025               Pop        132
# 37            2024            Latino        197
# 38            2023  Películas/Juegos        173
# 39            2026            Latino        197
# 40            2010               Pop        132
# 41            2023               NaN         -1
# 42            2024            Latino        197
# 43            2009            Latino        197
# 44            2009              Rock        152
# 45            2022            Cumbia         71
# 46            2018               Pop        132
# 47            2023  Películas/Juegos        173
# 48            2025            Cumbia         71

# %%
df_artista.to_csv("karina.csv", index=False)

# %%
def conseguir_canciones(artist_name, limit=50):     # Función para conseguir 50 canciones de la artista que quieras
    url = "https://api.deezer.com/search"           # URL base de la API para buscar
    params = {                                      # Para insertar los parámetros de la búsqueda
        "q": f'artist:"{artist_name}"',             # La API busca artista por q
        "limit": limit                              # Limit sirve para que saque solo 50
    }
    try:                                            # Bloque try/excep para llamar a la API y que nos dé el resultado
        response = requests.get(url, params=params)
        if response.status_code != 200:
            print("Error en la llamada a Deezer:", response.status_code)    # Si falla lo va a informar
            return pd.DataFrame([])                                         # Y también nos va a devolver el DF vacío
        data = response.json()                                              # Si no falla da la respuesta en json
    except Error as e:
        print("Error en la llamada a Deezer:", e)                           # Para que nos diga exactamente cuál es el error
        return pd.DataFrame([])

    canciones = data.get("data", [])                # Obtiene la lista de canciones
    lista_canciones = []                            # Lista donde se van a acumular las filas para el DF final

    for cancion in canciones:                       # Bucle para que itere con todas las canciones y nos vaya dando los datos
        track_id = cancion["id"]                    # Nos da el id de la canción
        track = requests.get(f"https://api.deezer.com/track/{track_id}").json()  # Pide todos los datos que estén en track
        album = requests.get(f"https://api.deezer.com/album/{track['album']['id']}").json() # Pide todos los datos que estén en album

        genre_id = album.get("genre_id")   # Extrae el ID del género de album
        genre_name = None                  # Creamos la variable "vacía"
        if album.get("genres") and album["genres"].get("data"):   # Le decimoa que en el caso de que genres exista en album
            genre_name = album["genres"]["data"][0].get("name")   # Entonces nos diga el primer género que aparezca (por si hay varios)

        tracks_type = "colaboracion" if len(track.get("contributors", [])) > 1 else album.get("record_type", "track")
        # Buscamos colaboraciones. Para ello, si en contributor aparece más de 1, entonces se trata de una colaboración
        # Si no, le decimos que nos ponga lo que aparezca en record_type que es single o album, y si no que ponga track
        release_year = track.get("release_date", "")[:4] if track.get("release_date") else None
        # Obtiene el año de lanzamiento solo si hay 4 cifras, si no pondrá None 
        lista_canciones.append({                   # Creamos un diccionario para añadir todos los datos que necesitamos
            "id_artista": track["artist"]["id"],
            "nombre_artista": artist_name,
            "titulo_cancion": track["title"],
            "titulo_album": track["album"]["title"],
            "tipo": tracks_type,
            "año_lanzamiento": release_year,
            "genero": genre_name,
            "id_genero": genre_id,
        })

    return pd.DataFrame(lista_canciones)        # Hacemos que nos devuelta el resultado en un DF

df_artista = conseguir_canciones("Massiel", limit=50)
df_artista
# Out:
#     id_artista nombre_artista  \
# 0       105903        Massiel
# 1     54310142        Massiel
# 2     10396026        Massiel
# 3      7890702        Massiel
# 4        65759        Massiel
# 5       129722        Massiel
# 6       129722        Massiel
# 7       129722        Massiel
# 8       129722        Massiel
# 9       129722        Massiel
# 10      129722        Massiel
# 11      129722        Massiel
# 12      129722        Massiel
# 13      129722        Massiel
# 14      129722        Massiel
# 15      355785        Massiel
# 16       64956        Massiel
# 17      129722        Massiel
# 18      129722        Massiel
# 19      129722        Massiel
# 20      129722        Massiel
# 21      129722        Massiel
# 22      129722        Massiel
# 23      129722        Massiel
# 24      129722        Massiel
# 25      129722        Massiel
# 26      129722        Massiel
# 27      129722        Massiel
# 28      129722        Massiel
# 29      129722        Massiel
# 30   375291411        Massiel
# 31      129722        Massiel
# 32    14385933        Massiel
# 33      129722        Massiel
# 34      129722        Massiel
# 35      129722        Massiel
# 36      129722        Massiel
# 37      129722        Massiel
# 38      129722        Massiel
# 39     4155433        Massiel
# 40     1347694        Massiel
# 41     1347694        Massiel
# 42     1347694        Massiel
# 43   123242282        Massiel
# 44      129722        Massiel
# 45      129722        Massiel
# 46      129722        Massiel
# 47      129722        Massiel
# 48      129722        Massiel
# 49      129722        Massiel
#
#                                        titulo_cancion  \
# 0                            Sur Fond De Marseillaise
# 1   Me Dijeron (feat. DVG, Magdiel CRZ, Risen, Lir...
# 2                                      Un Mundo Feliz
# 3                        Miles On It (COLDKIDS Remix)
# 4               Berlioz: Hymne des Marseillais, H 51a
# 5                                  Brindaremos por él
# 6                                          El Noa-Noa
# 7                                                Eres
# 8                                          La, La, La
# 9                                     Rosas en el Mar
# 10                                            El amor
# 11                               El amor (en directo)
# 12                                         Más fuerte
# 13                                      Aleluya No. 1
# 14                                 La, La, La (Remix)
# 15                                           El Credo
# 16                    Volver a los 17 (feat. Massiel)
# 17                                         Otra mujer
# 18                            La, la, la (en directo)
# 19                                       Deja la Flor
# 20                                Marinero (Marinaio)
# 21               Jenny la de los piratas (remastered)
# 22                                             Te amo
# 23                                        Lady Veneno
# 24                                   Rufo el Pescador
# 25                Canción de la moldavia (remastered)
# 26                                        Mañana será
# 27                                    Basta de peleas
# 28               Balada de maría sanders (remastered)
# 29                                               Amén
# 30                                             Lividi
# 31                                   Sola en libertad
# 32                                               Lies
# 33                                 La la La (En Vivo)
# 34                       Brindaremos por El (En Vivo)
# 35                                     Eres (En Vivo)
# 36                                 Marinero (En Vivo)
# 37                 Más Fuerte Que el Viento (En Vivo)
# 38                          Rosas en el Mar (En Vivo)
# 39                              Noche De Paz Tropical
# 40                                       Barquito mío
# 41                                 Gaspar en la noche
# 42                          Coda - A pasitos pequeños
# 43                   Butterfly (feat. Massiel) (Live)
# 44                                           Acordeón
# 45                          Todo lo que cambié por ti
# 46                             Voy a empezar de nuevo
# 47                                    Miradas de amor
# 48                                  Tiempos difíciles
# 49         Quiero amarte hasta el fondo de mi corazón
#
#                                          titulo_album          tipo  \
# 0                                    Demain c'est toi         album
# 1   Me Dijeron (feat. DVG, Magdiel CRZ, Risen, Lir...  colaboracion
# 2                                   Manual de Belleza  colaboracion
# 3                               Miles On It (Remixes)  colaboracion
# 4              Plácido Domingo - Artist Portrait 2007  colaboracion
# 5                                 Lo Mejor de Massiel         album
# 6                                 Lo Mejor de Massiel         album
# 7                                 Lo Mejor de Massiel         album
# 8                                 Lo Mejor de Massiel         album
# 9                                            Cuentame         album
# 10                                Lo Mejor de Massiel         album
# 11                          Massiel En Des. Concierto         album
# 12                                        iCollection         album
# 13                                           Orígenes         album
# 14                        Massiel: Sus Grandes Éxitos         album
# 15      Aromas de Libertad (Son Tus Perjúmenes Mujer)  colaboracion
# 16                 Rosa se esta buscando en el espejo  colaboracion
# 17                                  Corazón de hierro         album
# 18                          Massiel En Des. Concierto         album
# 19                                           Orígenes         album
# 20                                  Corazón de hierro         album
# 21                        Masiel Canta Bertolt Brecht         album
# 22                                Lo Mejor de Massiel         album
# 23                                Lo Mejor de Massiel         album
# 24                                           Orígenes         album
# 25                        Masiel Canta Bertolt Brecht         album
# 26                                  Tiempos dificiles         album
# 27                                  Corazón de hierro         album
# 28                        Masiel Canta Bertolt Brecht         album
# 29                                           Orígenes         album
# 30                                             Lividi        single
# 31                                         A Tí Mujer         album
# 32                                               Lies  colaboracion
# 33                     Idolos Latinos en Vivo, Vol. 2       compile
# 34                                    En Vina en Vivo         album
# 35                                    En Vina en Vivo         album
# 36                                    En Vina en Vivo         album
# 37                                    En Vina en Vivo         album
# 38                                    En Vina en Vivo         album
# 39                          It's a Tropical Christmas  colaboracion
# 40                                            Una Voz         album
# 41                                            Una Voz         album
# 42                                            Una Voz         album
# 43           Raw Talent Live The Soundtrack Las Vegas  colaboracion
# 44                                        iCollection         album
# 45                                        iCollection         album
# 46                                        iCollection         album
# 47                                        iCollection         album
# 48                                        iCollection         album
# 49                                        iCollection         album
#
#    año_lanzamiento       genero  id_genero
# 0             2005  Rap/Hip Hop        116
# 1             2023  Rap/Hip Hop        116
# 2             2026   Pop latino        138
# 3             2024        Dance        113
# 4             2004      Clásica         98
# 5             2013          Pop        132
# 6             2013          Pop        132
# 7             2013          Pop        132
# 8             2015          Pop        132
# 9             2001          Pop        132
# 10            2013          Pop        132
# 11            2014          Pop        132
# 12            2016          Pop        132
# 13            2018          Pop        132
# 14            2002          Pop        132
# 15            2007         Folk        466
# 16            2010        Niños         95
# 17            2014          Pop        132
# 18            2014          Pop        132
# 19            2018          Pop        132
# 20            2014          Pop        132
# 21            2005      Clásica         98
# 22            2013          Pop        132
# 23            2013          Pop        132
# 24            2018          Pop        132
# 25            2005      Clásica         98
# 26            2014          Pop        132
# 27            2014          Pop        132
# 28            2005      Clásica         98
# 29            2018          Pop        132
# 30            2026          Pop        132
# 31            2020          Pop        132
# 32            2018      Electro        106
# 33            2015          Pop        132
# 34            2016          Pop        132
# 35            2016          Pop        132
# 36            2016          Pop        132
# 37            2016          Pop        132
# 38            2016          Pop        132
# 39            2007          NaN         -1
# 40            2011       Latino        197
# 41            2011       Latino        197
# 42            2011       Latino        197
# 43            2008          Pop        132
# 44            2016          Pop        132
# 45            2016          Pop        132
# 46            2016          Pop        132
# 47            2016          Pop        132
# 48            2016          Pop        132
# 49            2016          Pop        132

# %%
df_artista.to_csv("massiel.csv", index=False)

# %%
LASTFM_API_KEY = "88d4c2ca98c2eacf39cbd94fdd2a63ba"

# %%
def obtener_info_lastfm(artist_name):
    
    LASTFM_BASE_URL = "https://ws.audioscrobbler.com/2.0/" #endpoint

    params = {                                             #parámetros para buscar
        "method": "artist.getInfo",
        "artist": artist_name,
        "api_key": LASTFM_API_KEY,
        "format": "json",
        "autocorrect": 1
    }

    data = requests.get(
        LASTFM_BASE_URL,
        params=params
    ).json()

    if "artist" not in data:
        return {
            "nombre_artista": artist_name,
            "biografía": None,
            "listeners": None,
            "playcount": None
        }

    artist = data["artist"]

    return {
        "nombre_artista": artist_name,
        "biografía": artist.get("bio", {}).get("summary"),
        "listeners": artist.get("stats", {}).get("listeners"),
        "playcount": artist.get("stats", {}).get("playcount")
    }
artistas = ["Janis Joplin", "Celia Cruz", "Aretha Franklin", "Lola Flores", "Nina Simone", "Silvie Vartan", "Patty Pravo", "Rita Pavone", "Karina", "Massiel"]

# Obtener info de cada artista
lista_info = [obtener_info_lastfm(artista) for artista in artistas]

# Convertir a DataFrame
df_info = pd.DataFrame(lista_info)
df_info
# Out:
#        artist_name                                          biography  \
# 0     Janis Joplin  Janis Joplin (born 19 January 1943 in Port Art...
# 1       Celia Cruz  Celia Cruz (born as Úrsula Hilaria Celia de la...
# 2  Aretha Franklin  Aretha Franklin (March 25, 1942 - August 16, 2...
# 3      Lola Flores  Lola Flores, "La Faraona" born January 21, 192...
# 4      Nina Simone  Eunice Kathleen Waymon (21 February 1933 – 21 ...
# 5    Silvie Vartan  Sylvie Vartan (born August 15, 1944 in Iskretz...
# 6      Patty Pravo  Patty Pravo (born Nicoletta Strambelli, 9 Apri...
# 7      Rita Pavone  Rita Pavone (born August 23, 1945 - Turin) is ...
# 8           Karina  There are multiple artists with this name:\n\n...
# 9          Massiel  Massiel (real name Maria de los Angeles Santam...
#
#   listeners playcount
# 0   1937889  34092778
# 1    587427   5043428
# 2   2932315  53111402
# 3     43166    351079
# 4   2995908  75195380
# 5    206481   1944467
# 6    113871   1015532
# 7     77769    554641
# 8    140669   1869320
# 9     39865    234507

# %%
df_info.to_csv("informacion_artist.csv", index=False)

# %%
df_info.to_csv("artist_similares", index=False)

# %%
import glob

archivos = glob.glob("*.csv")
artista_completo = pd.concat([pd.read_csv(f) for f in archivos], ignore_index=True)
artista_completo.to_csv("artista_completo.csv", index=False, encoding="utf-8")

# %%
import requests
import pandas as pd

LASTFM_BASE_URL = "https://ws.audioscrobbler.com/2.0/"

def obtener_info_lastfm(artist_name):
    params = {
        "method": "artist.getInfo",
        "artist": artist_name,
        "api_key": LASTFM_API_KEY,
        "format": "json",
        "autocorrect": 1
    }

    data = requests.get(LASTFM_BASE_URL, params=params).json()

    if "artist" not in data:
        return {
            "nombre_artista": artist_name,
            "biografía": None,
            "listeners": None,
            "playcount": None
        }

    artist = data["artist"]

    return {
        "nombre_artista": artist_name,
        "biografía": artist.get("bio", {}).get("summary"),
        "listeners": artist.get("stats", {}).get("listeners"),
        "playcount": artist.get("stats", {}).get("playcount")
    }


def obtener_artistas_similares(artist_name):
    params = {
        "method": "artist.getSimilar",
        "artist": artist_name,
        "api_key": LASTFM_API_KEY,
        "format": "json",
        "autocorrect": 1,
        "limit": 10
    }

    data = requests.get(LASTFM_BASE_URL, params=params).json()

    if "similarartists" not in data:
        return []

    return [
        artista["name"]
        for artista in data["similarartists"]["artist"]
    ]


artistas = ["Janis Joplin", "Celia Cruz", "Aretha Franklin", "Lola Flores", "Nina Simone",
            "Silvie Vartan", "Patty Pravo", "Rita Pavone", "Karina", "Massiel"]

lista_info = [obtener_info_lastfm(artista) for artista in artistas]
lista_similares = [obtener_artistas_similares(artista) for artista in artistas]


df_info = pd.DataFrame(lista_info)

df_similares = pd.DataFrame({
    "nombre_artista": artistas,
    "artistas_similares": lista_similares
})


df_completo = pd.merge(df_info, df_similares, on="nombre_artista", how="left")
df_completo
# Out:
#     nombre_artista                                          biografía  \
# 0     Janis Joplin  Janis Joplin (born 19 January 1943 in Port Art...
# 1       Celia Cruz  Celia Cruz (born as Úrsula Hilaria Celia de la...
# 2  Aretha Franklin  Aretha Franklin (March 25, 1942 - August 16, 2...
# 3      Lola Flores  Lola Flores, "La Faraona" born January 21, 192...
# 4      Nina Simone  Eunice Kathleen Waymon (21 February 1933 – 21 ...
# 5    Silvie Vartan  Sylvie Vartan (born August 15, 1944 in Iskretz...
# 6      Patty Pravo  Patty Pravo (born Nicoletta Strambelli, 9 Apri...
# 7      Rita Pavone  Rita Pavone (born August 23, 1945 - Turin) is ...
# 8           Karina  There are multiple artists with this name:\n\n...
# 9          Massiel  Massiel (real name Maria de los Angeles Santam...
#
#   listeners playcount                                 artistas_similares
# 0   1937889  34092778  [Big Brother & The Holding Company, Jimi Hendr...
# 1    587427   5043428  [Johnny Pacheco, Marc Anthony, Oscar D'León, R...
# 2   2932315  53111402  [Etta James, Gladys Knight & The Pips, Roberta...
# 3     43166    351079  [Rocío Jurado, Camarón de la Isla, Isabel Pant...
# 4   2995908  75195380  [Billie Holiday, Aretha Franklin, Etta James, ...
# 5    206481   1944467  [Sheila, Françoise Hardy, Brigitte Bardot, Gil...
# 6    113871   1015532  [Anna Oxa, Mina, Loredana Bertè, Marcella Bell...
# 7     77769    554641  [Edoardo Vianello, Little Tony, Peppino Di Cap...
# 8    140669   1869320  [Cazzu, NINGNING, Emilia, Ha*Ash, Amanda Migue...
# 9     39865    234507  [Mari Trini, Rocío Jurado, Paloma San Basilio,...

# %%
df_completo.to_csv("last_fm.csv", index=False)

# %%
import pandas as pd
import glob

ruta = "./concatenar/"
archivos = [f for f in glob.glob(ruta + "*.csv") if "artista_completo" not in f]
print("Archivos encontrados:", archivos)

artista_completo = pd.concat([pd.read_csv(f) for f in archivos], ignore_index=True)
artista_completo.to_csv(ruta + "artista_completo.csv", index=False, encoding="utf-8")

print(f"Filas totales: {len(artista_completo)}")
# Out:
# Archivos encontrados: ['./concatenar\\aretha.csv', './concatenar\\celia.csv', './concatenar\\janis.csv', './concatenar\\karina.csv', './concatenar\\lola.csv', './concatenar\\massiel.csv', './concatenar\\nina.csv', './concatenar\\patty.csv', './concatenar\\rita.csv', './concatenar\\silvie.csv']
# Filas totales: 454

# %%
print(archivos, "\n")
# Out:
# ['./concatenar\\aretha.csv', './concatenar\\celia.csv', './concatenar\\janis.csv', './concatenar\\karina.csv', './concatenar\\lola.csv', './concatenar\\massiel.csv', './concatenar\\nina.csv', './concatenar\\patty.csv', './concatenar\\rita.csv', './concatenar\\silvie.csv']

# %%
artista_completo
# Out:
#      id_artista nombre_artista  \
# 0           744    Nina Simone
# 1           744    Nina Simone
# 2           744    Nina Simone
# 3           744    Nina Simone
# 4           744    Nina Simone
# ..          ...            ...
# 485      129722        Massiel
# 486      129722        Massiel
# 487      129722        Massiel
# 488      129722        Massiel
# 489      129722        Massiel
#
#                                         titulo_cancion  \
# 0                                 I Put A Spell On You
# 1                                         Feeling Good
# 2    Ain't Got No - I Got Life (From the Musical Pr...
# 3                                            Sinnerman
# 4                            My Baby Just Cares for Me
# ..                                                 ...
# 485                          Todo lo que cambié por ti
# 486                             Voy a empezar de nuevo
# 487                                    Miradas de amor
# 488                                  Tiempos difíciles
# 489         Quiero amarte hasta el fondo de mi corazón
#
#                                    titulo_album   tipo  año_lanzamiento  \
# 0                          I Put A Spell On You  album             2018
# 1    Feeling Good: The Very Best Of Nina Simone  album             2019
# 2                             The Greatest Hits  album             2003
# 3    Feeling Good: The Very Best Of Nina Simone  album             2019
# 4                     My Baby Just Cares for Me  album             2009
# ..                                          ...    ...              ...
# 485                                 iCollection  album             2016
# 486                                 iCollection  album             2016
# 487                                 iCollection  album             2016
# 488                                 iCollection  album             2016
# 489                                 iCollection  album             2016
#
#     genero  id_genero
# 0     Jazz        129
# 1     Jazz        129
# 2      Pop        132
# 3     Jazz        129
# 4     Jazz        129
# ..     ...        ...
# 485    Pop        132
# 486    Pop        132
# 487    Pop        132
# 488    Pop        132
# 489    Pop        132
#
# [490 rows x 8 columns]

# %%
artista_completo["nombre_artista"].unique()
# Out:
# <StringArray>
# [                                   'Nina Simone',
#                                      'Celia Cruz',
#                                    'Ricky Martin',
#                                  'Johnny Pacheco',
#        'Celia Cruz, Rene Hernandez Y Su Orquesta',
#                                  'Jarabe de Palo',
#                                  'Gloria Estefan',
#                             'La Sonora Matancera',
#                                   'Gente De Zona',
#                                     'Tony Succar',
#                                    'Willie Colón',
#               'Big Brother & The Holding Company',
#                                    'Janis Joplin',
#                     'Paul Butterfield Blues Band',
#  'Big Brother & The Holding Company;Janis Joplin',
#                 'Various Artists - Kobra Records',
#                                         'Señor F',
#                                  'Rodrigo Cuevas',
#                                      'Marshmello',
#                                 'Plácido Domingo',
#                                         'Massiel',
#         'Carlos Mejía Godoy y los de Palacagüina',
#                                       'Rosa Leon',
#                                         'MASSIEL',
#                                     'Last & Loud',
#                                    'David Montes',
#                                  'Massiel Yanira',
#                              'Dancing Ritmo Crew']
# Length: 28, dtype: str

# %%
import os

ruta = "C:/Users/Teresa/Desktop/Adalab/proyectos/proyectos_grupo/proyecto2/concatenar/"

archivos = os.listdir(ruta)
print(f"Tienes {len(archivos)} archivos:")
for f in archivos:
    print(" -", f)
# Out:
# Tienes 11 archivos:
#  - aretha.csv
#  - artista_completo.csv
#  - celia.csv
#  - janis.csv
#  - karina.csv
#  - lola.csv
#  - massiel.csv
#  - nina.csv
#  - patty.csv
#  - rita.csv
#  - silvie.csv

# %%
import pandas as pd
import glob

ruta = "C:/Users/Teresa/Desktop/Adalab/proyectos/proyectos_grupo/proyecto2/concatenar/"

archivos = [f for f in glob.glob(ruta + "*.csv") if "artista_completo" not in f]
print("Archivos encontrados:", archivos)

artista_completo = pd.concat([pd.read_csv(f) for f in archivos], ignore_index=True)
artista_completo.to_csv(ruta + "artista_completo.csv", index=False, encoding="utf-8")

print(f"Filas totales: {len(artista_completo)}")
# Out:
# Archivos encontrados: ['C:/Users/Teresa/Desktop/Adalab/proyectos/proyectos_grupo/proyecto2/concatenar\\aretha.csv', 'C:/Users/Teresa/Desktop/Adalab/proyectos/proyectos_grupo/proyecto2/concatenar\\celia.csv', 'C:/Users/Teresa/Desktop/Adalab/proyectos/proyectos_grupo/proyecto2/concatenar\\janis.csv', 'C:/Users/Teresa/Desktop/Adalab/proyectos/proyectos_grupo/proyecto2/concatenar\\karina.csv', 'C:/Users/Teresa/Desktop/Adalab/proyectos/proyectos_grupo/proyecto2/concatenar\\lola.csv', 'C:/Users/Teresa/Desktop/Adalab/proyectos/proyectos_grupo/proyecto2/concatenar\\massiel.csv', 'C:/Users/Teresa/Desktop/Adalab/proyectos/proyectos_grupo/proyecto2/concatenar\\nina.csv', 'C:/Users/Teresa/Desktop/Adalab/proyectos/proyectos_grupo/proyecto2/concatenar\\patty.csv', 'C:/Users/Teresa/Desktop/Adalab/proyectos/proyectos_grupo/proyecto2/concatenar\\rita.csv', 'C:/Users/Teresa/Desktop/Adalab/proyectos/proyectos_grupo/proyecto2/concatenar\\silvie.csv']
# Filas totales: 490

# %%
## Conexión a Mysql
def conexion_mysql():
    try:
        conexion = mysql.connector.connect(
             host = '127.0.0.1',
             user = 'root',
             password = 'guitarra'
        )
        print("Conexion exitosa")
        return conexion
    except Exception as e:
        print(f"Error al conectar: {e}")
        
conexion = conexion_mysql()
# Out:
# Conexion exitosa

# %%
cursor = conexion.cursor()

# %%
#Creación Base de Datos

try:
    cursor = conexion.cursor()
    query_crear_bbdd = """
    CREATE DATABASE IF NOT EXISTS musicstream
    CHARACTER SET utf8mb4
    COLLATE utf8mb4_unicode_ci
    """
    cursor.execute(query_crear_bbdd)
    print("Query existosa")
except Error as e:
    print(e)
# Out:
# Query existosa

# %%
cursor.execute("use musicstream")
query_crear_tabla = '''CREATE TABLE artistas (
                        id_artista INT PRIMARY KEY AUTO_INCREMENT, 
                        nombre_artista VARCHAR(50) NOT NULL
                        );'''
cursor.execute(query_crear_tabla)
print ("Tabla creada correctamente")
# Out:
# Tabla creada correctamente

# %%
cursor.execute("USE musicstream")

# %%
df_tabla_artistas = pd.read_csv(r"C:/Users/Teresa/Desktop/Adalab/proyectos/proyectos_grupo/proyecto2/git_teresa/proyecto-da-promo-67-modulo2-team-3/Deezer/artistas_completo_deezer.csv",
    encoding="utf-8"
)
df_tabla_artistas = df_tabla_artistas[["nombre_artista"]].drop_duplicates()
for index, fila in df_tabla_artistas.iterrows():
    query_insert = """
    INSERT INTO artistas (nombre_artista)
    VALUES (%s)
    """
    valores = (fila["nombre_artista"],)
    cursor.execute(query_insert, valores)
conexion.commit()
print("Datos insertados correctamente")
# Out:
# Datos insertados correctamente

# %%
ruta = "C:/Users/Teresa/Desktop/Adalab/proyectos/proyectos_grupo/proyecto2/concatenar/"

# %%
print(os.listdir())
# Out:
# ['.git', '.gitignore', 'Deezer', 'divas_inic.ipynb', 'LFM', 'README.md']

# %%
cursor.execute("use musicstream")
query_crear_tabla = """
CREATE TABLE canciones (
    id_cancion INT PRIMARY KEY AUTO_INCREMENT,
    id_artista INT NOT NULL,
    titulo_cancion VARCHAR(300) NOT NULL,
    titulo_album VARCHAR(300),
    tipo VARCHAR(100),
    año_lanzamiento INT,
    genero VARCHAR(100),
    id_genero FLOAT,
    FOREIGN KEY (id_artista)
    REFERENCES artistas(id_artista)
);
"""
cursor.execute(query_crear_tabla)
print("Tabla canciones creada correctamente")
# Out:
# Tabla canciones creada correctamente

# %%
df_tabla_canciones = pd.read_csv(r"C:/Users/Teresa/Desktop/Adalab/proyectos/proyectos_grupo/proyecto2/git_teresa/proyecto-da-promo-67-modulo2-team-3/Deezer/artistas_completo_deezer.csv",
    encoding="utf-8"
)
for index, fila in df_tabla_canciones.iterrows():
    query_id_artista = """
    SELECT id_artista
    FROM artistas
    WHERE nombre_artista = %s
    """
    cursor.execute(
        query_id_artista,
        (fila["nombre_artista"],)
    )
    resultado = cursor.fetchone()
    id_artista = resultado[0]
    query_insert = """
    INSERT INTO canciones (
        id_artista,
        titulo_cancion,
        titulo_album,
        tipo,
        año_lanzamiento,
        genero,
        id_genero
    )
    VALUES (%s, %s, %s, %s, %s, %s, %s)
    """
    valores = (
        id_artista,
        fila["titulo_cancion"],
        fila["titulo_album"],
        fila["tipo"],
        fila["año_lanzamiento"],
        fila["genero"]
        if pd.notna(fila["genero"])
        else None,
        fila["id_genero"]
        if pd.notna(fila["id_genero"])
        else None
    )
    cursor.execute(query_insert, valores)
conexion.commit()
print("Datos insertados correctamente")
# Out:
# Datos insertados correctamente

# %%
query_crear_tabla = """
CREATE TABLE informacion_artistas (
    id_info INT PRIMARY KEY AUTO_INCREMENT,
    id_artista INT NOT NULL,
    nombre_artista VARCHAR(50),
    biografia TEXT,
    listeners BIGINT,
    playcount BIGINT,
    artistas_similares TEXT,
    FOREIGN KEY (id_artista)
    REFERENCES artistas(id_artista)
);
"""
cursor.execute(query_crear_tabla)
print("Tabla informacion_artistas creada correctamente")
# Out:
# Tabla informacion_artistas creada correctamente

# %%
df_lfm = pd.read_csv(r"C:/Users/Teresa/Desktop/Adalab/proyectos/proyectos_grupo/proyecto2/git_teresa/proyecto-da-promo-67-modulo2-team-3/LFM/artistas_completo_LFM.csv",
    encoding="utf-8"
)
for index, fila in df_lfm.iterrows():
    query_id_artista = """
    SELECT id_artista
    FROM artistas
    WHERE nombre_artista = %s
    """
    cursor.execute(
        query_id_artista,
        (fila["nombre_artista"],)
    )
    resultado = cursor.fetchone()
    id_artista = resultado[0]
    query_insert = """
    INSERT INTO informacion_artistas (
        id_artista,
        nombre_artista,
        biografia,
        listeners,
        playcount,
        artistas_similares
    )
    VALUES (%s, %s, %s, %s, %s, %s)
    """
    valores = (
        id_artista,
        fila["nombre_artista"],
        fila["biografia"],
        fila["listeners"],
        fila["playcount"],
        fila["artistas_similares"]
    )
    cursor.execute(query_insert, valores)
conexion.commit()
print("Datos insertados correctamente")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 15
#      10 cursor.execute(
#      11     query_id_artista,
#      12     (fila["nombre_artista"],)
#      13 )
#      14 resultado = cursor.fetchone()
# ---> 15 id_artista = resultado[0]
#      16 query_insert = """
#      17 INSERT INTO informacion_artistas (
#      18     id_artista,
#    (...)     25 VALUES (%s, %s, %s, %s, %s, %s)
#      26 """
#      27 valores = (
#      28     id_artista,
#      29     fila["nombre_artista"],
#    (...)     33     fila["artistas_similares"]
#      34 )
#
# TypeError: 'NoneType' object is not subscriptable

# %%
#Rocio
for index, fila in df_last.iterrows():
    query_id_artista = """
    SELECT id_artista
    FROM artistas
    WHERE nombre_artista = %s
    """
    cursor.execute(
        query_id_artista,
        (fila["nombre_artista"],)
    )
    resultado = cursor.fetchone()
    if resultado is None:
        print(f"Artista no encontrado: {fila['nombre_artista']}")
        continue

    id_artista = resultado[0]
    query_insert = """
    INSERT INTO informacion_artistas (
        id_artista,
        nombre_artista,
        biografia,
        listeners,
        playcount,
        artistas_similares
    )
    VALUES (%s, %s, %s, %s, %s, %s)
    """
    valores = (
        id_artista,
        fila["nombre_artista"],
        fila["biografia"],
        fila["listeners"],
        fila["playcount"],
        fila["artistas_similares"]
    )
    cursor.execute(query_insert, valores)
connection.commit()
print("Datos insertados correctamente")
