# %%
import pandas as pd
Rocio = pd.read_csv("artistas_completo_last_rocio.csv")
Teresa = pd.read_csv("last_fm.csv")
Nati = pd.read_csv("artistas_completo_LFM_Nati.csv")
Cris = pd.read_csv("artistas_completo_LFM_Cris.csv")
artistas_completo_LFM = pd.concat([Rocio, Teresa, Nati, Cris], ignore_index=True)
artistas_completo_LFM.to_csv("artistas_completo_LFM.csv", index=False, encoding="utf-8")
